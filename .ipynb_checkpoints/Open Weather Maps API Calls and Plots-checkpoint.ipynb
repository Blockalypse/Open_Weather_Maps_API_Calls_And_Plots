# %% [markdown]
# # Analysis
#
# ----
#
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from time import sleep
import json

import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/city_weather_data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List
# ---

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
weather=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
#created dataframe 
weather_df = pd.DataFrame({"City": cities})

#add columns
weather_df["Country"] = ""
weather_df["Temperature (F)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Wind Speed (mph)"] = ""
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""

# %%
weather_df.head()
# Out:
#           City Country Temperature (F) Humidity (%) Cloudiness (%)  \
# 0    geraldton
# 1  kamenolomni
# 2      baculin
# 3      ushuaia
# 4         marl
#
#   Wind Speed (mph) Latitude Longitude
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Perform API Calls
# ---
# Performing a weather check on each city using a series of successive API calls.

# %%
# OpenWeatherMap API Key
api_key = "6531fb771bd4c6120244bdacb4b0a890"

# %%
row_count = 0

for index, row in weather_df.iterrows():
    
    # Starting URL for Weather Map API Call
    query_url = "http://api.openweathermap.org/data/2.5/weather?q=%s&units=IMPERIAL&appid=%s" %(row["City"], api_key)
    # Parse the Json and retrieve data
    response = requests.get(query_url).json()
   
    
    try:
        # Print to Logger
        print(f'Initializing: City {row_count} {response["name"]}, {response["sys"]["country"]}.')
        print(query_url)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        row_count = row_count + 1
        
        # Load Data into Dataframe
        weather_df.set_value(index, "City", response["name"])
        weather_df.set_value(index, "Country", response["sys"]["country"])
        weather_df.set_value(index, "Temperature (F)", response["main"]["temp"])
        weather_df.set_value(index, "Humidity (%)", response["main"]["humidity"])
        weather_df.set_value(index, "Cloudiness (%)", response["clouds"]["all"])
        weather_df.set_value(index, "Wind Speed (mph)", response["wind"]["speed"])
        weather_df.set_value(index, "Latitude", response["coord"]["lat"])
        weather_df.set_value(index, "Longitude", response["coord"]["lon"])
        
      
    #If error, skip the city     
    except:
        
        print("Missing field/result... skipping.")
        
    #while row_count % 5 == 0:
            #time.sleep(2)
#Indicate that Data Loading is Complete       
print("retrieval complete")
# Out:
# Initializing: City 0 Geraldton, CA.
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mrpam\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Initializing: City 1 Kamenolomni, RU.
# http://api.openweathermap.org/data/2.5/weather?q=kamenolomni&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 2 Baculin, PH.
# http://api.openweathermap.org/data/2.5/weather?q=baculin&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 3 Ushuaia, AR.
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 4 Marl, DE.
# http://api.openweathermap.org/data/2.5/weather?q=marl&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 5 Aklavik, CA.
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 6 Bethel, US.
# http://api.openweathermap.org/data/2.5/weather?q=bethel&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 7 The Valley, AI.
# http://api.openweathermap.org/data/2.5/weather?q=the valley&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 8 Albany, US.
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 9 Menemen, TR.
# http://api.openweathermap.org/data/2.5/weather?q=menemen&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 10 Shache, CN.
# http://api.openweathermap.org/data/2.5/weather?q=shache&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 11 Saint Anthony, US.
# http://api.openweathermap.org/data/2.5/weather?q=saint anthony&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 12 Shimoda, JP.
# http://api.openweathermap.org/data/2.5/weather?q=shimoda&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 13 Petropavlovsk-Kamchatskiy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 14 Rikitea, PF.
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 15 Kapaa, US.
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 16 Punta Arenas, CL.
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 17 Berlin, DE.
# http://api.openweathermap.org/data/2.5/weather?q=berlin&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 18 Piacabucu, BR.
# http://api.openweathermap.org/data/2.5/weather?q=piacabucu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 19 Hilo, US.
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 20 Ambilobe, MG.
# http://api.openweathermap.org/data/2.5/weather?q=ambilobe&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 21 Lorengau, PG.
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 22 Alpena, US.
# http://api.openweathermap.org/data/2.5/weather?q=alpena&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 23 Seddon, NZ.
# http://api.openweathermap.org/data/2.5/weather?q=seddon&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 24 Lavrentiya, RU.
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 25 Bluff, AU.
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 26 Townsville, AU.
# http://api.openweathermap.org/data/2.5/weather?q=townsville&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 27 Port Alfred, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 28 Butaritari, KI.
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 29 Yerbogachen, RU.
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 30 Ajnala, IN.
# http://api.openweathermap.org/data/2.5/weather?q=ajnala&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 31 Jardim, BR.
# http://api.openweathermap.org/data/2.5/weather?q=jardim&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 32 Ahipara, NZ.
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 33 Saskylakh, RU.
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 34 Faanui, PF.
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 35 Margate, AU.
# http://api.openweathermap.org/data/2.5/weather?q=margate&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 36 Karlshamn, SE.
# http://api.openweathermap.org/data/2.5/weather?q=karlshamn&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 37 Tuktoyaktuk, CA.
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 38 At-Bashi, KG.
# http://api.openweathermap.org/data/2.5/weather?q=at-bashi&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 39 Allende, MX.
# http://api.openweathermap.org/data/2.5/weather?q=allende&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 40 Thompson, CA.
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 41 Bredasdorp, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 42 Cherskiy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 43 Avarua, CK.
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 44 Harper, US.
# http://api.openweathermap.org/data/2.5/weather?q=harper&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 45 Hermanus, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 46 Salalah, OM.
# http://api.openweathermap.org/data/2.5/weather?q=salalah&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 47 Camargo, MX.
# http://api.openweathermap.org/data/2.5/weather?q=camargo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 48 Tiksi, RU.
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 49 Krasnyy Chikoy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=krasnyy chikoy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 50 Yellowknife, CA.
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 51 Ahuimanu, US.
# http://api.openweathermap.org/data/2.5/weather?q=ahuimanu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 52 Kaitangata, NZ.
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 53 Saint-Philippe, CA.
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 54 Arraial do Cabo, BR.
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 55 Bambous Virieux, MU.
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 56 Port Lincoln, AU.
# http://api.openweathermap.org/data/2.5/weather?q=port lincoln&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 57 Atar, MR.
# http://api.openweathermap.org/data/2.5/weather?q=atar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 58 Denpasar, ID.
# http://api.openweathermap.org/data/2.5/weather?q=denpasar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 59 Molinella, IT.
# http://api.openweathermap.org/data/2.5/weather?q=molinella&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 60 Hofn, IS.
# http://api.openweathermap.org/data/2.5/weather?q=hofn&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 61 Lewiston, US.
# http://api.openweathermap.org/data/2.5/weather?q=lewiston&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 62 Chuy, UY.
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 63 Iqaluit, CA.
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 64 Boyuibe, BO.
# http://api.openweathermap.org/data/2.5/weather?q=boyuibe&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 65 Rawson, AR.
# http://api.openweathermap.org/data/2.5/weather?q=rawson&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 66 Sao Filipe, CV.
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 67 Upernavik, GL.
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 68 Dakar, SN.
# http://api.openweathermap.org/data/2.5/weather?q=dakar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 69 Surt, LY.
# http://api.openweathermap.org/data/2.5/weather?q=surt&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 70 Kudahuvadhoo, MV.
# http://api.openweathermap.org/data/2.5/weather?q=kudahuvadhoo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 71 Porlamar, VE.
# http://api.openweathermap.org/data/2.5/weather?q=porlamar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 72 Mataura, NZ.
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 73 Kidal, ML.
# http://api.openweathermap.org/data/2.5/weather?q=kidal&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 74 Prince Rupert, CA.
# http://api.openweathermap.org/data/2.5/weather?q=prince rupert&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 75 Puerto Penasco, MX.
# http://api.openweathermap.org/data/2.5/weather?q=puerto penasco&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 76 Aguimes, ES.
# http://api.openweathermap.org/data/2.5/weather?q=aguimes&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 77 Barrow, AR.
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 78 Hobart, AU.
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 79 Busselton, AU.
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 80 Kushiro, JP.
# http://api.openweathermap.org/data/2.5/weather?q=kushiro&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 81 Nurobod, UZ.
# http://api.openweathermap.org/data/2.5/weather?q=nurobod&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 82 Dikson, RU.
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 83 Norman Wells, CA.
# http://api.openweathermap.org/data/2.5/weather?q=norman wells&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 84 Kloulklubed, PW.
# http://api.openweathermap.org/data/2.5/weather?q=kloulklubed&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 85 Tasiilaq, GL.
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 86 Pevek, RU.
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 87 Jamestown, AU.
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 88 Joniskis, LT.
# http://api.openweathermap.org/data/2.5/weather?q=joniskis&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 89 Saldanha, PT.
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 90 Shahrud, IR.
# http://api.openweathermap.org/data/2.5/weather?q=shahrud&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 91 Provideniya, RU.
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 92 Yar-Sale, RU.
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 93 Ribeira Grande, PT.
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 94 Khatanga, RU.
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 95 Orotukan, RU.
# http://api.openweathermap.org/data/2.5/weather?q=orotukan&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 96 Batagay, RU.
# http://api.openweathermap.org/data/2.5/weather?q=batagay&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 97 Cabo San Lucas, MX.
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 98 Corsicana, US.
# http://api.openweathermap.org/data/2.5/weather?q=corsicana&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 99 Sandakan, MY.
# http://api.openweathermap.org/data/2.5/weather?q=sandakan&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 100 Grand Gaube, MU.
# http://api.openweathermap.org/data/2.5/weather?q=grand gaube&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 101 Vestmannaeyjar, IS.
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 102 Lebu, ET.
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 103 Sal Rei, CV.
# http://api.openweathermap.org/data/2.5/weather?q=sal rei&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 104 Port Elizabeth, US.
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 105 Ozernovskiy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=ozernovskiy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 106 Puerto Ayora, EC.
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 107 Venado Tuerto, AR.
# http://api.openweathermap.org/data/2.5/weather?q=venado tuerto&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 108 Esperance, TT.
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 109 Mahebourg, MU.
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 110 Dullewala, PK.
# http://api.openweathermap.org/data/2.5/weather?q=dullewala&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 111 Oktyabrskiy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 112 Olinda, EC.
# http://api.openweathermap.org/data/2.5/weather?q=olinda&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 113 Georgetown, GY.
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 114 Portland, US.
# http://api.openweathermap.org/data/2.5/weather?q=portland&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 115 Vaini, IN.
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 116 Baramati, IN.
# http://api.openweathermap.org/data/2.5/weather?q=baramati&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 117 Cidreira, BR.
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 118 Victoria, BN.
# http://api.openweathermap.org/data/2.5/weather?q=victoria&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 119 Nago, IT.
# http://api.openweathermap.org/data/2.5/weather?q=nago&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 120 Kodiak, US.
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 121 Aguas Verdes, EC.
# http://api.openweathermap.org/data/2.5/weather?q=aguas verdes&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 122 Marawi, PH.
# http://api.openweathermap.org/data/2.5/weather?q=marawi&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 123 Neuquen, AR.
# http://api.openweathermap.org/data/2.5/weather?q=neuquen&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 124 Peniche, PT.
# http://api.openweathermap.org/data/2.5/weather?q=peniche&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 125 Luderitz, NA.
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 126 Sabang, PH.
# http://api.openweathermap.org/data/2.5/weather?q=sabang&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 127 Port Augusta, AU.
# http://api.openweathermap.org/data/2.5/weather?q=port augusta&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 128 Ancud, CL.
# http://api.openweathermap.org/data/2.5/weather?q=ancud&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 129 Codrington, AU.
# http://api.openweathermap.org/data/2.5/weather?q=codrington&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 130 Igrim, RU.
# http://api.openweathermap.org/data/2.5/weather?q=igrim&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 131 Mackenzie, CA.
# http://api.openweathermap.org/data/2.5/weather?q=mackenzie&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 132 Atherton, GB.
# http://api.openweathermap.org/data/2.5/weather?q=atherton&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 133 Leningradskiy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 134 Xingyi, CN.
# http://api.openweathermap.org/data/2.5/weather?q=xingyi&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 135 Basco, US.
# http://api.openweathermap.org/data/2.5/weather?q=basco&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 136 Alofi, NU.
# http://api.openweathermap.org/data/2.5/weather?q=alofi&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 137 Cape Town, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=cape town&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 138 East London, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=east london&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 139 Broome, GB.
# http://api.openweathermap.org/data/2.5/weather?q=broome&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 140 Zhigansk, RU.
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 141 Lagoa, PT.
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 142 Uyuni, BO.
# http://api.openweathermap.org/data/2.5/weather?q=uyuni&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 143 Hun, BE.
# http://api.openweathermap.org/data/2.5/weather?q=hun&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 144 Malangali, TZ.
# http://api.openweathermap.org/data/2.5/weather?q=malangali&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 145 Vanimo, PG.
# http://api.openweathermap.org/data/2.5/weather?q=vanimo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 146 Puerto Ayacucho, CO.
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayacucho&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 147 Sojat, IN.
# http://api.openweathermap.org/data/2.5/weather?q=sojat&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 148 Uribia, CO.
# http://api.openweathermap.org/data/2.5/weather?q=uribia&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 149 Cartagena, ES.
# http://api.openweathermap.org/data/2.5/weather?q=cartagena&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 150 Narsaq, GL.
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 151 Inhambane, MZ.
# http://api.openweathermap.org/data/2.5/weather?q=inhambane&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 152 Katangli, RU.
# http://api.openweathermap.org/data/2.5/weather?q=katangli&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 153 Komsomolskiy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 154 Saint-Francois, FR.
# http://api.openweathermap.org/data/2.5/weather?q=saint-francois&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 155 Havre-Saint-Pierre, CA.
# http://api.openweathermap.org/data/2.5/weather?q=havre-saint-pierre&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 156 Torbay, CA.
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 157 Kaeo, NZ.
# http://api.openweathermap.org/data/2.5/weather?q=kaeo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 158 Neepawa, CA.
# http://api.openweathermap.org/data/2.5/weather?q=neepawa&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 159 Umea, SE.
# http://api.openweathermap.org/data/2.5/weather?q=umea&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 160 Anloga, GH.
# http://api.openweathermap.org/data/2.5/weather?q=anloga&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 161 Panzhihua, CN.
# http://api.openweathermap.org/data/2.5/weather?q=panzhihua&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 162 Merrill, US.
# http://api.openweathermap.org/data/2.5/weather?q=merrill&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 163 Kuldur, RU.
# http://api.openweathermap.org/data/2.5/weather?q=kuldur&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 164 Tripoli, GR.
# http://api.openweathermap.org/data/2.5/weather?q=tripoli&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 165 Kruisfontein, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 166 Kauhajoki, FI.
# http://api.openweathermap.org/data/2.5/weather?q=kauhajoki&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 167 Coihaique, CL.
# http://api.openweathermap.org/data/2.5/weather?q=coihaique&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 168 Beyneu, KZ.
# http://api.openweathermap.org/data/2.5/weather?q=beyneu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 169 Macaubas, BR.
# http://api.openweathermap.org/data/2.5/weather?q=macaubas&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 170 Katsuura, JP.
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 171 Clinton, US.
# http://api.openweathermap.org/data/2.5/weather?q=clinton&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 172 Marfino, RU.
# http://api.openweathermap.org/data/2.5/weather?q=marfino&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 173 Stettler, CA.
# http://api.openweathermap.org/data/2.5/weather?q=stettler&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 174 Orange Walk, JM.
# http://api.openweathermap.org/data/2.5/weather?q=orange walk&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 175 Hobyo, SO.
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 176 Lucapa, AO.
# http://api.openweathermap.org/data/2.5/weather?q=lucapa&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 177 Atuona, PF.
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 178 Klaksvik, FO.
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 179 Bereda, ES.
# http://api.openweathermap.org/data/2.5/weather?q=bereda&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 180 Guarda, PT.
# http://api.openweathermap.org/data/2.5/weather?q=guarda&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 181 San Quintin, PH.
# http://api.openweathermap.org/data/2.5/weather?q=san quintin&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 182 Hithadhoo, MV.
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 183 Karratha, AU.
# http://api.openweathermap.org/data/2.5/weather?q=karratha&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 184 Avera, US.
# http://api.openweathermap.org/data/2.5/weather?q=avera&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 185 Jaciara, BR.
# http://api.openweathermap.org/data/2.5/weather?q=jaciara&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 186 Bubaque, GW.
# http://api.openweathermap.org/data/2.5/weather?q=bubaque&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 187 Talnakh, RU.
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 188 Namatanai, PG.
# http://api.openweathermap.org/data/2.5/weather?q=namatanai&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 189 Mareeba, AU.
# http://api.openweathermap.org/data/2.5/weather?q=mareeba&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 190 Jacareacanga, BR.
# http://api.openweathermap.org/data/2.5/weather?q=jacareacanga&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 191 Fairbanks, US.
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Missing field/result... skipping.
# Initializing: City 192 Westport, IE.
# http://api.openweathermap.org/data/2.5/weather?q=westport&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 193 Inta, RU.
# http://api.openweathermap.org/data/2.5/weather?q=inta&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 194 Alice Springs, AU.
# http://api.openweathermap.org/data/2.5/weather?q=alice springs&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 195 Qaanaaq, GL.
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 196 Ta Khmau, KH.
# http://api.openweathermap.org/data/2.5/weather?q=ta khmau&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 197 Mount Isa, AU.
# http://api.openweathermap.org/data/2.5/weather?q=mount isa&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 198 Nabire, ID.
# http://api.openweathermap.org/data/2.5/weather?q=nabire&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 199 Wanning, AT.
# http://api.openweathermap.org/data/2.5/weather?q=wanning&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 200 Spornoye, RU.
# http://api.openweathermap.org/data/2.5/weather?q=spornoye&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 201 Ambunti, PG.
# http://api.openweathermap.org/data/2.5/weather?q=ambunti&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 202 Samarai, PG.
# http://api.openweathermap.org/data/2.5/weather?q=samarai&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 203 Ixtapa, MX.
# http://api.openweathermap.org/data/2.5/weather?q=ixtapa&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 204 New Norfolk, AU.
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 205 Zhezkazgan, KZ.
# http://api.openweathermap.org/data/2.5/weather?q=zhezkazgan&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 206 Dunedin, NZ.
# http://api.openweathermap.org/data/2.5/weather?q=dunedin&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 207 Hamilton, BM.
# http://api.openweathermap.org/data/2.5/weather?q=hamilton&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 208 Sinnamary, GF.
# http://api.openweathermap.org/data/2.5/weather?q=sinnamary&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 209 Vila Velha, BR.
# http://api.openweathermap.org/data/2.5/weather?q=vila velha&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 210 Mahon, IE.
# http://api.openweathermap.org/data/2.5/weather?q=mahon&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 211 Pisco, PE.
# http://api.openweathermap.org/data/2.5/weather?q=pisco&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 212 Broken Hill, AU.
# http://api.openweathermap.org/data/2.5/weather?q=broken hill&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 213 Graaff-Reinet, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=graaff-reinet&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 214 Anadyr, RU.
# http://api.openweathermap.org/data/2.5/weather?q=anadyr&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 215 Pierre, US.
# http://api.openweathermap.org/data/2.5/weather?q=pierre&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 216 Oranjemund, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 217 Carnarvon, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 218 Tateyama, JP.
# http://api.openweathermap.org/data/2.5/weather?q=tateyama&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 219 Nikolskoye, RU.
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 220 Araceli, PH.
# http://api.openweathermap.org/data/2.5/weather?q=araceli&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 221 Novopokrovka, RU.
# http://api.openweathermap.org/data/2.5/weather?q=novopokrovka&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 222 Los Llanos de Aridane, ES.
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 223 Port Blair, IN.
# http://api.openweathermap.org/data/2.5/weather?q=port blair&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 224 Dryden, CA.
# http://api.openweathermap.org/data/2.5/weather?q=dryden&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 225 Nanortalik, GL.
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 226 Khingansk, RU.
# http://api.openweathermap.org/data/2.5/weather?q=khingansk&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 227 Clyde River, CA.
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 228 Fort Nelson, CA.
# ...
# Initializing: City 456 Shetpe, KZ.
# http://api.openweathermap.org/data/2.5/weather?q=shetpe&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 457 Swan Hill, AU.
# http://api.openweathermap.org/data/2.5/weather?q=swan hill&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 458 Mirskoy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=mirskoy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 459 Solok, ID.
# http://api.openweathermap.org/data/2.5/weather?q=solok&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 460 Dubbo, AU.
# http://api.openweathermap.org/data/2.5/weather?q=dubbo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 461 Lompoc, US.
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 462 Hegang, CN.
# http://api.openweathermap.org/data/2.5/weather?q=hegang&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 463 Talcahuano, CL.
# http://api.openweathermap.org/data/2.5/weather?q=talcahuano&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 464 Camopi, GF.
# http://api.openweathermap.org/data/2.5/weather?q=camopi&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 465 Urucara, BR.
# http://api.openweathermap.org/data/2.5/weather?q=urucara&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 466 Kathu, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=kathu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 467 Flinders, AU.
# http://api.openweathermap.org/data/2.5/weather?q=flinders&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 468 Strzelin, PL.
# http://api.openweathermap.org/data/2.5/weather?q=strzelin&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 469 Aflao, TG.
# http://api.openweathermap.org/data/2.5/weather?q=aflao&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 470 Yatou, CM.
# http://api.openweathermap.org/data/2.5/weather?q=yatou&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 471 Hailar, CN.
# http://api.openweathermap.org/data/2.5/weather?q=hailar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 472 Steinbach, CA.
# http://api.openweathermap.org/data/2.5/weather?q=steinbach&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 473 Senno, RU.
# http://api.openweathermap.org/data/2.5/weather?q=senno&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 474 Nanjing, CN.
# http://api.openweathermap.org/data/2.5/weather?q=nanjing&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 475 Husavik, CA.
# http://api.openweathermap.org/data/2.5/weather?q=husavik&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 476 Ipameri, BR.
# http://api.openweathermap.org/data/2.5/weather?q=ipameri&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 477 Pecos, US.
# http://api.openweathermap.org/data/2.5/weather?q=pecos&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 478 Khabary, RU.
# http://api.openweathermap.org/data/2.5/weather?q=khabary&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 479 Aksu, KZ.
# http://api.openweathermap.org/data/2.5/weather?q=aksu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 480 Joshimath, IN.
# http://api.openweathermap.org/data/2.5/weather?q=joshimath&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 481 Caravelas, BR.
# http://api.openweathermap.org/data/2.5/weather?q=caravelas&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 482 Paka, HR.
# http://api.openweathermap.org/data/2.5/weather?q=paka&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 483 Poum, MK.
# http://api.openweathermap.org/data/2.5/weather?q=poum&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 484 Sao Miguel, BR.
# http://api.openweathermap.org/data/2.5/weather?q=sao miguel&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 485 Roald, NO.
# http://api.openweathermap.org/data/2.5/weather?q=roald&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 486 Port-Gentil, GA.
# http://api.openweathermap.org/data/2.5/weather?q=port-gentil&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 487 Kavieng, PG.
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 488 Hirara, JP.
# http://api.openweathermap.org/data/2.5/weather?q=hirara&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 489 Udachnyy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=udachnyy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 490 Coruripe, BR.
# http://api.openweathermap.org/data/2.5/weather?q=coruripe&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 491 Kyaikkami, MM.
# http://api.openweathermap.org/data/2.5/weather?q=kyaikkami&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 492 Chichimila, MX.
# http://api.openweathermap.org/data/2.5/weather?q=chichimila&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 493 Lodwar, KE.
# http://api.openweathermap.org/data/2.5/weather?q=lodwar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 494 Ulaanbaatar, MN.
# http://api.openweathermap.org/data/2.5/weather?q=ulaanbaatar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 495 Wick, GB.
# http://api.openweathermap.org/data/2.5/weather?q=wick&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 496 Whakatane, NZ.
# http://api.openweathermap.org/data/2.5/weather?q=whakatane&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 497 Kanigoro, ID.
# http://api.openweathermap.org/data/2.5/weather?q=kanigoro&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 498 Bud, NO.
# http://api.openweathermap.org/data/2.5/weather?q=bud&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 499 Payakumbuh, ID.
# http://api.openweathermap.org/data/2.5/weather?q=payakumbuh&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 500 Eureka, US.
# http://api.openweathermap.org/data/2.5/weather?q=eureka&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 501 Lydenburg, ZA.
# http://api.openweathermap.org/data/2.5/weather?q=lydenburg&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 502 Boyolangu, ID.
# http://api.openweathermap.org/data/2.5/weather?q=boyolangu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 503 Mattru, SL.
# http://api.openweathermap.org/data/2.5/weather?q=mattru&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 504 Sioux Lookout, CA.
# http://api.openweathermap.org/data/2.5/weather?q=sioux lookout&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 505 Krasnokamensk, RU.
# http://api.openweathermap.org/data/2.5/weather?q=krasnokamensk&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 506 Saint-Jean-de-la-Ruelle, FR.
# http://api.openweathermap.org/data/2.5/weather?q=saint-jean-de-la-ruelle&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 507 San Nicolas, HN.
# http://api.openweathermap.org/data/2.5/weather?q=san nicolas&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 508 Winsum, NL.
# http://api.openweathermap.org/data/2.5/weather?q=winsum&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 509 Namie, JP.
# http://api.openweathermap.org/data/2.5/weather?q=namie&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 510 Antofagasta, CL.
# http://api.openweathermap.org/data/2.5/weather?q=antofagasta&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 511 Elat, CM.
# http://api.openweathermap.org/data/2.5/weather?q=elat&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 512 Coquimbo, CL.
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 513 Gualaquiza, EC.
# http://api.openweathermap.org/data/2.5/weather?q=gualaquiza&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 514 San Jose del Golfo, GT.
# http://api.openweathermap.org/data/2.5/weather?q=san jose del golfo&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 515 Deputatskiy, RU.
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 516 Wana, PK.
# http://api.openweathermap.org/data/2.5/weather?q=wana&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 517 Maanshan, CN.
# http://api.openweathermap.org/data/2.5/weather?q=maanshan&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 518 Aracruz, BR.
# http://api.openweathermap.org/data/2.5/weather?q=aracruz&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 519 Were Ilu, ET.
# http://api.openweathermap.org/data/2.5/weather?q=were ilu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 520 Hunchun, CN.
# http://api.openweathermap.org/data/2.5/weather?q=hunchun&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 521 Derzhavinsk, KZ.
# http://api.openweathermap.org/data/2.5/weather?q=derzhavinsk&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 522 Buala, SB.
# http://api.openweathermap.org/data/2.5/weather?q=buala&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Missing field/result... skipping.
# Initializing: City 523 Marystown, CA.
# http://api.openweathermap.org/data/2.5/weather?q=marystown&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 524 Oslomej, MK.
# http://api.openweathermap.org/data/2.5/weather?q=oslomej&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 525 Anahuac, US.
# http://api.openweathermap.org/data/2.5/weather?q=anahuac&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 526 Pringsewu, ID.
# http://api.openweathermap.org/data/2.5/weather?q=pringsewu&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 527 Olga, US.
# http://api.openweathermap.org/data/2.5/weather?q=olga&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 528 Ichhawar, IN.
# http://api.openweathermap.org/data/2.5/weather?q=ichhawar&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 529 Saint-Felicien, CA.
# http://api.openweathermap.org/data/2.5/weather?q=saint-felicien&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 530 Bireun, ID.
# http://api.openweathermap.org/data/2.5/weather?q=bireun&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 531 Elbistan, TR.
# http://api.openweathermap.org/data/2.5/weather?q=elbistan&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Missing field/result... skipping.
# Initializing: City 532 Mahanoro, MG.
# http://api.openweathermap.org/data/2.5/weather?q=mahanoro&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Initializing: City 533 Bontang, ID.
# http://api.openweathermap.org/data/2.5/weather?q=bontang&units=IMPERIAL&appid=6531fb771bd4c6120244bdacb4b0a890
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# retrieval complete

# %%
#visualize, check data 
weather_df.head()
# Out:
#           City Country Temperature (F) Humidity (%) Cloudiness (%)  \
# 0    Geraldton      CA            33.8           50             75
# 1  Kamenolomni      RU              59           77             20
# 2      Baculin      PH           88.07           55             41
# 3      Ushuaia      AR            51.8           66             40
# 4         Marl      DE           40.32           93             40
#
#   Wind Speed (mph) Latitude Longitude
# 0              1.7    49.72    -86.95
# 1             6.71    47.67     40.21
# 2                4     7.45    126.58
# 3             8.05   -54.81    -68.31
# 4             2.24    51.65      7.08

# %%
#drop rows with missing values 
weather_df = weather_df.dropna(how='any')

# %%
#convert to graphable values 
weather_df['Temperature (F)'] = pd.to_numeric(weather_df['Temperature (F)'])
weather_df['Humidity (%)'] = pd.to_numeric(weather_df['Humidity (%)'])
weather_df['Cloudiness (%)'] = pd.to_numeric(weather_df['Cloudiness (%)'])
weather_df['Wind Speed (mph)'] = pd.to_numeric(weather_df['Wind Speed (mph)'])
weather_df['Latitude'] = pd.to_numeric(weather_df['Latitude'])
weather_df['Longitude'] = pd.to_numeric(weather_df['Longitude'])

# %%
#Check data type of each column 
weather_df.dtypes
# Out:
# City                 object
# Country              object
# Temperature (F)     float64
# Humidity (%)        float64
# Cloudiness (%)      float64
# Wind Speed (mph)    float64
# Latitude            float64
# Longitude           float64
# dtype: object

# %% [markdown]
# ## Export City Data to .csv
# ---

# %%
# Save the revised Data Frame as a csv
weather_df.to_csv(
    "output_data/city_weather_data.csv", encoding="utf-8", index=False)

# Visualize
weather_df.head()
# Out:
#           City Country  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0    Geraldton      CA            33.80          50.0            75.0
# 1  Kamenolomni      RU            59.00          77.0            20.0
# 2      Baculin      PH            88.07          55.0            41.0
# 3      Ushuaia      AR            51.80          66.0            40.0
# 4         Marl      DE            40.32          93.0            40.0
#
#    Wind Speed (mph)  Latitude  Longitude
# 0              1.70     49.72     -86.95
# 1              6.71     47.67      40.21
# 2              4.00      7.45     126.58
# 3              8.05    -54.81     -68.31
# 4              2.24     51.65       7.08

# %% [markdown]
# # Plotting the Data
# ---

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], alpha=0.9, edgecolors='black', label="City")

# Incorporate the other graph properties
plt.style.use('fivethirtyeight')
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.ylim(-40, 125)
plt.xlim(-90, 90)

# Save the figure as .png
plt.savefig("output_data/Lat_Temp.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], alpha=0.4, color="green", edgecolors='black', label="City")

# Incorporate the other graph properties
plt.style.use('Solarize_Light2')
plt.title(f"City Latitude vs. Humidty (%)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)
plt.ylim(-10, 120)
plt.xlim(-90, 90)

# Save the figure as .png
plt.savefig("output_data/Lat_Humid.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness (%)"], alpha=0.5, edgecolors='black', label="City")

# Incorporate the other graph properties
plt.style.use('seaborn-dark-palette')
plt.title(f"City Latitude vs. Cloudiness (%)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)
plt.ylim(-10, 110)
plt.xlim(-90, 90)

# Save the figure as .png
plt.savefig("output_data/Lat_Cloud.png")

#Show graph
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed (mph)"], color="red", alpha=0.5, edgecolors='black', label="City")

# Incorporate the other graph properties
plt.style.use('fivethirtyeight')
plt.title(f"City Latitude vs. Wind Speed (mph))")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.ylim(-10, 100)
plt.xlim(-90, 90)

# Save the figure as .png
plt.savefig("output_data/Lat_Wind.png")

# Show plot
plt.show()
